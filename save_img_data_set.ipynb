# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
from tqdm import tqdm

# %%
data = pd.read_csv("imgs_details.csv")

# %%
data
# Out:
#       Unnamed: 0                                           img_link  \
# 0              0  https://cdn.pixabay.com/photo/2022/03/06/05/30...
# 1              1  https://cdn.pixabay.com/photo/2022/04/07/11/45...
# 2              2  https://cdn.pixabay.com/photo/2022/02/28/15/28...
# 3              3  https://cdn.pixabay.com/photo/2022/04/04/02/52...
# 4              4  https://cdn.pixabay.com/photo/2022/04/09/18/06...
# ...          ...                                                ...
# 5483        5483  https://cdn.pixabay.com/photo/2021/08/26/18/32...
# 5484        5484  https://cdn.pixabay.com/photo/2020/05/19/05/42...
# 5485        5485  https://cdn.pixabay.com/photo/2022/02/18/08/40...
# 5486        5486  https://cdn.pixabay.com/photo/2021/11/10/21/11...
# 5487        5487  https://cdn.pixabay.com/photo/2022/02/19/14/23...
#
#                                          tags  likes  comments
# 0           Clouds, Sky, Atmosphere, Blue Sky    196        55
# 1              Bird, Ornithology, Hummingbird     76        20
# 2         Sea, Rainbow, Rainfall, Subtropical    282       106
# 3        Cherry Blossoms, Road, Japan, Sakura     42        11
# 4              Cape Marguerite, Flower, Plant     39        15
# ...                                       ...    ...       ...
# 5483        Grain, Spike, Grain Field, Stalks     33        15
# 5484  Weaver, Bird, Feathers, Yellow, Perched    107        28
# 5485      Bird, Raptor, Wings, Osprey, Flying      8         7
# 5486      Olives, Dark Olives, Olive Oil, Oil     37        29
# 5487        Snowdrops, Flowers, White Flowers      3         0
#
# [5488 rows x 5 columns]

# %%
# def download(link ,img_pathpath):
#     res = requests.get(data["img_link"])
#     file = open("IMG2/"+path,"wb")
#     file.write(res.content)
#     file.close

# %%
ref = 10000
i = 1
res = requests.get(link)
for link in data["img_link"]:
    res = requests.get(link)
    img_id = "A"+str(i+ref)[1:]
    i+=1
    img_path = "IMG2/"+img_id + ".jpg"
    
    file = open(img_path,"wb")
    file.write(res.content)
    file.close()
